# %%
var('x,y')
f(x,y) = x*exp(x+y)
var('t')
# Out:
# t

# %%
plot(f(1 -2*t,1 + 1*t ) , (t,0,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
PLOT3D = plot3d(f(x,y),(x,-2,1),(y,-2,1),color='yellow',projection='orthographic')

# %%
PLOT3D + parametric_plot3d( (0.3-2*t,1+t,f(0.3-2*t,1+t)) , (t,0,1))
# Out:
# Graphics3d Object
