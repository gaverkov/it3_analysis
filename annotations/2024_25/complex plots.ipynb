# %%
var('z')
f(z) = 50/(2-z)/(3-z)
CPLOT=complex_plot(f,(-4,4),(-2,2),plot_points=1000,contoured=True)
CIRCLE=circle((0,0),2,zorder=1)
POINTS=points([(2,0),(3,0)],color='black',size=40,zorder=2)
PLOT=CPLOT+CIRCLE+POINTS
PLOT.show()
#PLOT.save("complex_plot_rational.pdf")
# Out:
# verbose 0 (163: primitive.py, options) WARNING: Ignoring option 'contoured'=True
# verbose 0 (163: primitive.py, options)
# The allowed options for ComplexPlot defined by a 1000 x 1000 data grid are:
#     interpolation  What interpolation method to use
#     plot_points    How many points to use for plotting precision
#
# verbose 0 (163: primitive.py, options) WARNING: Ignoring option 'contoured'=True
# verbose 0 (163: primitive.py, options)
# The allowed options for ComplexPlot defined by a 1000 x 1000 data grid are:
#     interpolation  What interpolation method to use
#     plot_points    How many points to use for plotting precision
#
# verbose 0 (163: primitive.py, options) WARNING: Ignoring option 'contoured'=True
# verbose 0 (163: primitive.py, options)
# The allowed options for ComplexPlot defined by a 1000 x 1000 data grid are:
#     interpolation  What interpolation method to use
#     plot_points    How many points to use for plotting precision
# Graphics object consisting of 3 graphics primitives

# %%
complex_plot(z^5 + z - 1 + 1/z, (-3, 3), (-3, 3), plot_points=300)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('x,y')
print( abs(f(2+I*3)))
# Out:
# 5/3*sqrt(10)
